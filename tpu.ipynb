# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tpu = pd.read_csv('https://raw.githubusercontent.com/hauzanabhan/tugas-2/master/tpu.csv')

# %%
tpu.head()
# Out:
#                   Daerah  Jumlah Makam  Kapasitas
# 0          Desa Sumberjo             4      12130
# 1  Kelurahan Songgokerto             3      29900
# 2      Desa Pesanggrahan             4      18751
# 3      Kelurahan Ngaglik             4      20500
# 4        Kelurahan Sisir             2      14800

# %%
tpu.tail()
# Out:
#                  Daerah  Jumlah Makam  Kapasitas
# 19          Desa Pendem             6      36650
# 20        Desa Mojorejo             2       1510
# 21         Desa Tlekung             3       6400
# 22         Desa Junrejo             4       7585
# 23  Kelurahan Dadaprejo             3       9500

# %%
tpu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
# Daerah          24 non-null object
# Jumlah Makam    24 non-null int64
# Kapasitas       24 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 704.0+ bytes

# %%
tpu.describe()
# Out:
#        Jumlah Makam     Kapasitas
# count     24.000000     24.000000
# mean       3.958333  15348.000000
# std        2.156470   7915.140571
# min        2.000000   1510.000000
# 25%        2.750000   9375.000000
# 50%        3.000000  15000.000000
# 75%        4.250000  18487.750000
# max       10.000000  36650.000000

# %%
tpu.groupby('Kapasitas').mean()
# Out:
#            Jumlah Makam
# Kapasitas
# 1510                  2
# 6400                  3
# 7001                  3
# 7075                  7
# 7585                  4
# 9000                  2
# 9500                  3
# 10700                 2
# 12130                 4
# 13000                 4
# 14800                 2
# 15000                 2
# 16000                 3
# 17500                 3
# 18250                 5
# 18400                10
# 18751                 4
# 20500                 4
# 21200                 5
# 25000                 9
# 29900                 3
# 36650                 6

# %%
tpu.groupby('Jumlah Makam').mean()
# Out:
#                  Kapasitas
# Jumlah Makam
# 2             11001.666667
# 3             14828.714286
# 4             14393.200000
# 5             19725.000000
# 6             36650.000000
# 7              7075.000000
# 9             25000.000000
# 10            18400.000000

# %%
tpu.groupby('Daerah').mean()
# Out:
#                        Jumlah Makam  Kapasitas
# Daerah
# Desa Beji                         2      15000
# Desa Bulukerto                    5      18250
# Desa Bumiaji                      5      21200
# Desa Giripurno                    3      17500
# Desa Gunungsari                  10      18400
# Desa Junrejo                      4       7585
# Desa Mojorejo                     2       1510
# Desa Oro Oro Ombo                 3      16000
# Desa Pandanrejo                   2      10700
# Desa Pendem                       6      36650
# Desa Pesanggrahan                 4      18751
# Desa Punten                       2       9000
# Desa Sidomulyo                    4      13000
# Desa Sumberbrantas                2      15000
# Desa Sumbergondo                  7       7075
# Desa Sumberjo                     4      12130
# Desa Tlekung                      3       6400
# Desa Torongrejo                   3      17500
# Desa Tulungrejo                   9      25000
# ...

# %%
x = ('Desa Beji(2)','Desa Bulukerto(5)','Desa Bumiaji(5)','Desa Giripurno(3)','Desa Gunungsari(10)','Desa Junrejo(4)','Desa Mojorejo(2)','Desa Oro Oro Ombo(3)','Desa Pandanrejo(2)','Desa Pendem(6)','Desa Pesanggrahan(4)','Desa Punten(2)','Desa Sidomulyo(4)','Desa Sumberbrantas(2)','Desa Sumbergondo(7)','Desa Sumberejo(4)','Desa Tlenkung(3)','Desa Torongrejo(3)','Desa Tulungrejo(9)','Kelurahan Dadaprejo(3)','Kelurahan Ngaglik(4)','Kelurahan Sisir(2)','Kelurahan Songgokerto(3)','Kelurahan Temas(3)')
print(x)
# Out:
# ('Desa Beji(2)', 'Desa Bulukerto(5)', 'Desa Bumiaji(5)', 'Desa Giripurno(3)', 'Desa Gunungsari(10)', 'Desa Junrejo(4)', 'Desa Mojorejo(2)', 'Desa Oro Oro Ombo(3)', 'Desa Pandanrejo(2)', 'Desa Pendem(6)', 'Desa Pesanggrahan(4)', 'Desa Punten(2)', 'Desa Sidomulyo(4)', 'Desa Sumberbrantas(2)', 'Desa Sumbergondo(7)', 'Desa Sumberejo(4)', 'Desa Tlenkung(3)', 'Desa Torongrejo(3)', 'Desa Tulungrejo(9)', 'Kelurahan Dadaprejo(3)', 'Kelurahan Ngaglik(4)', 'Kelurahan Sisir(2)', 'Kelurahan Songgokerto(3)', 'Kelurahan Temas(3)')

# %%
y = (15000,18250,21200,17500,18400,7585,1510,16000,10700,36650,18751,9000,13000,15000,7075,12130,6400,17500,25000,9500,20500,14800,29900,7001)
print(y)
# Out:
# (15000, 18250, 21200, 17500, 18400, 7585, 1510, 16000, 10700, 36650, 18751, 9000, 13000, 15000, 7075, 12130, 6400, 17500, 25000, 9500, 20500, 14800, 29900, 7001)

# %%
plt.plot(x,y, 'o', color='blue')
plt.title('Grafik TPU di Kota Batu')
plt.ylabel('Kapasitas')
plt.xlabel('Daerah(Jumlah Makam)')
# Out:
# Text(0.5, 0, 'Daerah(Jumlah Makam)')
